# %% [markdown]
# # Phase 7: TCAV
#
# Phase 7 moves from concept descriptions to concept sensitivity.
#
# This notebook runs the TCAV pipeline implemented in `src/tcav.py` and `scripts/run_phase7_tcav.py`:
#
# - select positive and negative AwA2 examples for each semantic concept;
# - extract pooled activations from an internal ResNet layer;
# - train one Concept Activation Vector per concept;
# - compute whether the concept direction increases target class scores;
# - save CSV reports and visual summaries.

# %%
from pathlib import Path
from IPython.display import Image, display
import csv
import subprocess
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent

CANDIDATE_MANIFESTS = [
    PROJECT_ROOT / 'data' / 'AWA2_subset_background20' / 'awa2_manifest_subset.csv',
    PROJECT_ROOT / 'data' / 'AWA2' / 'awa2_manifest_debug.csv',
    PROJECT_ROOT / 'data' / 'AWA2' / 'awa2_manifest.csv',
]
MANIFEST = next((path for path in CANDIDATE_MANIFESTS if path.exists()), None)
if MANIFEST is None:
    raise FileNotFoundError('No AwA2 manifest found.')

METADATA_ROOT = PROJECT_ROOT / 'data' / 'AWA2'
CHECKPOINT = PROJECT_ROOT / 'outputs' / 'checkpoints' / 'best_resnet50_awa2.pt'

CONCEPTS = ['stripes', 'furry', 'hooves', 'horns', 'flippers']
TARGET_CLASSES = []  # leave empty to let the script choose compact concept-relevant targets

SCORE_CSV = PROJECT_ROOT / 'outputs' / 'reports' / 'phase7_tcav_scores_notebook.csv'
CAV_CSV = PROJECT_ROOT / 'outputs' / 'reports' / 'phase7_cav_summary_notebook.csv'
HEATMAP_OUTPUT = PROJECT_ROOT / 'outputs' / 'figures' / 'phase7_tcav_heatmap_notebook.png'
BAR_OUTPUT = PROJECT_ROOT / 'outputs' / 'figures' / 'phase7_tcav_top_scores_notebook.png'

print('manifest:', MANIFEST)
print('metadata_root:', METADATA_ROOT)
print('checkpoint:', CHECKPOINT, 'exists=', CHECKPOINT.exists())
print('concepts:', CONCEPTS)
print('target_classes:', TARGET_CLASSES or 'auto')
# Out:
# manifest: /home/ely-01/DeepLearning/project/Deep_Learning_XAI/data/AWA2_subset_background20/awa2_manifest_subset.csv
# metadata_root: /home/ely-01/DeepLearning/project/Deep_Learning_XAI/data/AWA2
# checkpoint: /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/checkpoints/best_resnet50_awa2.pt exists= True
# concepts: ['stripes', 'furry', 'hooves', 'horns', 'aquatic']
# target_classes: auto

# %% [markdown]
# ## Run TCAV
#
# This cell trains CAVs for the selected concepts and computes class-level TCAV scores. The default layer is `layer3`: it is still high-level, but unlike the final `layer4` output it keeps a non-linear part of ResNet downstream, so TCAV scores do not collapse to class-level constants.

# %%
cmd = [
    sys.executable,
    str(PROJECT_ROOT / 'scripts' / 'run_phase7_tcav.py'),
    '--manifest', str(MANIFEST),
    '--metadata-root', str(METADATA_ROOT),
    '--checkpoint', str(CHECKPOINT),
    '--concepts', *CONCEPTS,
    '--layer', 'layer3',
    '--score-output', str(SCORE_CSV),
    '--cav-output', str(CAV_CSV),
    '--heatmap-output', str(HEATMAP_OUTPUT),
    '--bar-output', str(BAR_OUTPUT),
    '--max-target-classes', '10',
    '--max-concept-examples', '200',
    '--max-eval-per-class', '40',
]
if TARGET_CLASSES:
    cmd.extend(['--target-classes', *TARGET_CLASSES])

print(' '.join(cmd))
completed = subprocess.run(cmd, cwd=PROJECT_ROOT, text=True, capture_output=True)
print(completed.stdout)
if completed.stderr:
    print(completed.stderr)
completed.check_returncode()
# Out:
# /home/ely-01/DeepLearning/project/Deep_Learning_XAI/.venv/bin/python /home/ely-01/DeepLearning/project/Deep_Learning_XAI/scripts/run_phase7_tcav.py --manifest /home/ely-01/DeepLearning/project/Deep_Learning_XAI/data/AWA2_subset_background20/awa2_manifest_subset.csv --metadata-root /home/ely-01/DeepLearning/project/Deep_Learning_XAI/data/AWA2 --checkpoint /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/checkpoints/best_resnet50_awa2.pt --concepts stripes furry hooves horns aquatic --layer layer3 --score-output /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/reports/phase7_tcav_scores_notebook.csv --cav-output /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/reports/phase7_cav_summary_notebook.csv --heatmap-output /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/figures/phase7_tcav_heatmap_notebook.png --bar-output /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/figures/phase7_tcav_top_scores_notebook.png --max-target-classes 10 --max-concept-examples 200 --max-eval-per-class 40
#
# 2026-07-10 12:47:38 | INFO | run_phase7_tcav | manifest=/home/ely-01/DeepLearning/project/Deep_Learning_XAI/data/AWA2_subset_background20/awa2_manifest_subset.csv
# 2026-07-10 12:47:38 | INFO | run_phase7_tcav | checkpoint=/home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/checkpoints/best_resnet50_awa2.pt
# 2026-07-10 12:47:38 | INFO | run_phase7_tcav | num_classes=20 device=cpu
# 2026-07-10 12:47:38 | INFO | run_phase7_tcav | metadata_root=/home/ely-01/DeepLearning/project/Deep_Learning_XAI/data/AWA2/Animals_with_Attributes2
# 2026-07-10 12:47:38 | INFO | src.data | Loaded manifest split=train with 2782 samples, 20 visible classes, 20 mapped classes from /home/ely-01/DeepLearning/project/Deep_Learning_XAI/data/AWA2_subset_background20/awa2_manifest_subset.csv
# 2026-07-10 12:47:38 | INFO | src.data | Loaded manifest split=val with 596 samples, 20 visible classes, 20 mapped classes from /home/ely-01/DeepLearning/project/Deep_Learning_XAI/data/AWA2_subset_background20/awa2_manifest_subset.csv
# 2026-07-10 12:47:38 | INFO | src.data | Loaded manifest split=test with 596 samples, 20 visible classes, 20 mapped classes from /home/ely-01/DeepLearning/project/Deep_Learning_XAI/data/AWA2_subset_background20/awa2_manifest_subset.csv
# 2026-07-10 12:47:38 | INFO | src.model | Built ResNet50 classifier: num_classes=20 pretrained=False total_params=23549012 trainable=22104084 frozen=1444928
# 2026-07-10 12:47:38 | INFO | src.model | Module conv1    trainable_params=0 total_params=9408 trainable=False
# 2026-07-10 12:47:38 | INFO | src.model | Module bn1      trainable_params=0 total_params=128 trainable=False
# 2026-07-10 12:47:38 | INFO | src.model | Module layer1   trainable_params=0 total_params=215808 trainable=False
# 2026-07-10 12:47:38 | INFO | src.model | Module layer2   trainable_params=0 total_params=1219584 trainable=False
# 2026-07-10 12:47:38 | INFO | src.model | Module layer3   trainable_params=7098368 total_params=7098368 trainable=True
# 2026-07-10 12:47:38 | INFO | src.model | Module layer4   trainable_params=14964736 total_params=14964736 trainable=True
# 2026-07-10 12:47:38 | INFO | src.model | Module fc       trainable_params=40980 total_params=40980 trainable=True
# 2026-07-10 12:47:39 | INFO | run_phase7_tcav | loaded checkpoint: /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/checkpoints/best_resnet50_awa2.pt
# 2026-07-10 12:47:39 | INFO | run_phase7_tcav | processing concept=stripes
# 2026-07-10 12:47:55 | INFO | src.tcav | trained CAV concept=stripes layer=layer3 positives=200 negatives=200 acc=1.000 loss=0.0006
# 2026-07-10 12:48:11 | INFO | run_phase7_tcav | processing concept=furry
# 2026-07-10 12:48:28 | INFO | src.tcav | trained CAV concept=furry layer=layer3 positives=200 negatives=200 acc=1.000 loss=0.0010
# 2026-07-10 12:48:44 | INFO | run_phase7_tcav | processing concept=hooves
# 2026-07-10 12:49:01 | INFO | src.tcav | trained CAV concept=hooves layer=layer3 positives=200 negatives=200 acc=1.000 loss=0.0004
# 2026-07-10 12:49:16 | INFO | run_phase7_tcav | processing concept=horns
# 2026-07-10 12:49:31 | INFO | src.tcav | trained CAV concept=horns layer=layer3 positives=140 negatives=200 acc=1.000 loss=0.0007
# 2026-07-10 12:49:45 | INFO | run_phase7_tcav | processing concept=aquatic
# 2026-07-10 12:49:45 | WARNING | run_phase7_tcav | skipping concept=aquatic: Unknown concept 'aquatic'. First available concepts are: black, white, blue, brown, gray, orange, red, yellow, patches, spots, stripes, furry, hairless, toughskin, big, small, bulbous, lean, flippers, hands
# 2026-07-10 12:49:45 | INFO | run_phase7_tcav | saved /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/reports/phase7_cav_summary_notebook.csv
# 2026-07-10 12:49:45 | INFO | run_phase7_tcav | saved /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/reports/phase7_tcav_scores_notebook.csv
# 2026-07-10 12:49:46 | INFO | run_phase7_tcav | saved /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/figures/phase7_tcav_heatmap_notebook.png
# 2026-07-10 12:49:46 | INFO | run_phase7_tcav | saved /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/figures/phase7_tcav_top_scores_notebook.png
# 2026-07-10 12:49:46 | INFO | run_phase7_tcav | Phase 7 complete: scores=/home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/reports/phase7_tcav_scores_notebook.csv cavs=/home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/reports/phase7_cav_summary_notebook.csv heatmap=/home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/figures/phase7_tcav_heatmap_notebook.png barplot=/home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/figures/phase7_tcav_top_scores_notebook.png

# %% [markdown]
# ## Inspect TCAV Figures
#
# The heatmap shows the fraction of positive directional derivatives for every target class and concept. The bar plot highlights the strongest class-concept sensitivities.

# %%
for figure in [HEATMAP_OUTPUT, BAR_OUTPUT]:
    print(figure)
    if figure.exists():
        display(Image(filename=str(figure)))
    else:
        print('missing figure:', figure)
# Out:
# /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/figures/phase7_tcav_heatmap_notebook.png
# /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/figures/phase7_tcav_top_scores_notebook.png

# %% [markdown]
# ## Inspect CSV Reports
#
# `phase7_cav_summary` describes how each CAV was trained. `phase7_tcav_scores` contains the class-concept sensitivity scores used by the figures.

# %%
for csv_path in [CAV_CSV, SCORE_CSV]:
    print('\n', csv_path)
    if not csv_path.exists():
        print('missing csv')
        continue
    with csv_path.open('r', newline='', encoding='utf-8') as handle:
        rows = list(csv.DictReader(handle))
    print('rows:', len(rows))
    for row in rows[:8]:
        print(row)
# Out:
#  /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/reports/phase7_cav_summary_notebook.csv
# rows: 4
# {'concept': 'stripes', 'layer': 'layer3', 'pool': 'avg', 'positive_count': '200', 'negative_count': '200', 'positive_threshold': '0.75', 'negative_threshold': '0.25', 'cav_train_accuracy': '1.0', 'cav_final_loss': '0.0006195258465595543', 'positive_classes': 'zebra:108; tiger:92', 'negative_classes': 'sheep:18; leopard:14; bobcat:14; buffalo:14; elephant:13; hippopotamus:12; walrus:11; blue+whale:11'}
# {'concept': 'furry', 'layer': 'layer3', 'pool': 'avg', 'positive_count': '200', 'negative_count': '200', 'positive_threshold': '0.75', 'negative_threshold': '0.25', 'cav_train_accuracy': '1.0', 'cav_final_loss': '0.0009592776768840849', 'positive_classes': 'wolf:33; lion:32; grizzly+bear:32; tiger:29; giant+panda:28; polar+bear:26; bobcat:20', 'negative_classes': 'seal:29; dolphin:27; giraffe:26; blue+whale:26; humpback+whale:26; elephant:25; walrus:25; hippopotamus:16'}
# {'concept': 'hooves', 'layer': 'layer3', 'pool': 'avg', 'positive_count': '200', 'negative_count': '200', 'positive_threshold': '0.75', 'negative_threshold': '0.25', 'cav_train_accuracy': '1.0', 'cav_final_loss': '0.0004397875745780766', 'positive_classes': 'zebra:108; antelope:92', 'negative_classes': 'polar+bear:20; dolphin:17; seal:17; walrus:16; hippopotamus:15; blue+whale:14; grizzly+bear:13; elephant:13'}
# {'concept': 'horns', 'layer': 'layer3', 'pool': 'avg', 'positive_count': '140', 'negative_count': '200', 'positive_threshold': '0.75', 'negative_threshold': '0.25', 'cav_train_accuracy': '1.0', 'cav_final_loss': '0.0006640063365921378', 'positive_classes': 'antelope:140', 'negative_classes': 'hippopotamus:21; seal:16; elephant:15; zebra:14; tiger:13; lion:12; leopard:11; giant+panda:11'}
#
#  /home/ely-01/DeepLearning/project/Deep_Learning_XAI/outputs/reports/phase7_tcav_scores_notebook.csv
# rows: 40
# {'concept': 'stripes', 'target_class': 'zebra', 'target_label': '19', 'layer': 'layer3', 'pool': 'avg', 'tcav_score': '0.4000000059604645', 'mean_directional_derivative': '-2.678821147128474e-05', 'std_directional_derivative': '0.0002885421272367239', 'n_eval': '30', 'cav_train_accuracy': '1.0', 'positive_count': '200', 'negative_count': '200'}
# {'concept': 'stripes', 'target_class': 'tiger', 'target_label': '16', 'layer': 'layer3', 'pool': 'avg', 'tcav_score': '0.7666666507720947', 'mean_directional_derivative': '0.00025750926579348743', 'std_directional_derivative': '0.0005023226840421557', 'n_eval': '30', 'cav_train_accuracy': '1.0', 'positive_count': '200', 'negative_count': '200'}
# {'concept': 'stripes', 'target_class': 'humpback+whale', 'target_label': '10', 'layer': 'layer3', 'pool': 'avg', 'tcav_score': '0.20000000298023224', 'mean_directional_derivative': '-0.00021166636724956334', 'std_directional_derivative': '0.00022521984647028148', 'n_eval': '30', 'cav_train_accuracy': '1.0', 'positive_count': '200', 'negative_count': '200'}
# {'concept': 'stripes', 'target_class': 'blue+whale', 'target_label': '1', 'layer': 'layer3', 'pool': 'avg', 'tcav_score': '0.0', 'mean_directional_derivative': '-0.0004566949501167983', 'std_directional_derivative': '0.00016154276090674102', 'n_eval': '26', 'cav_train_accuracy': '1.0', 'positive_count': '200', 'negative_count': '200'}
# {'concept': 'stripes', 'target_class': 'bobcat', 'target_label': '2', 'layer': 'layer3', 'pool': 'avg', 'tcav_score': '0.03333333507180214', 'mean_directional_derivative': '-0.0003685281262733042', 'std_directional_derivative': '0.00021157259470783174', 'n_eval': '30', 'cav_train_accuracy': '1.0', 'positive_count': '200', 'negative_count': '200'}
# {'concept': 'stripes', 'target_class': 'leopard', 'target_label': '11', 'layer': 'layer3', 'pool': 'avg', 'tcav_score': '0.3333333432674408', 'mean_directional_derivative': '-8.885325951268896e-05', 'std_directional_derivative': '0.00016043585492298007', 'n_eval': '30', 'cav_train_accuracy': '1.0', 'positive_count': '200', 'negative_count': '200'}
# {'concept': 'stripes', 'target_class': 'walrus', 'target_label': '17', 'layer': 'layer3', 'pool': 'avg', 'tcav_score': '0.13333334028720856', 'mean_directional_derivative': '-0.0003023675817530602', 'std_directional_derivative': '0.00021312059834599495', 'n_eval': '30', 'cav_train_accuracy': '1.0', 'positive_count': '200', 'negative_count': '200'}
# {'concept': 'stripes', 'target_class': 'wolf', 'target_label': '18', 'layer': 'layer3', 'pool': 'avg', 'tcav_score': '0.3333333432674408', 'mean_directional_derivative': '-5.0166148866992444e-05', 'std_directional_derivative': '0.00021434844529721886', 'n_eval': '30', 'cav_train_accuracy': '1.0', 'positive_count': '200', 'negative_count': '200'}

# %% [markdown]
# ## Reading the Scores
#
# A high TCAV score means that the target class logit often increases along that concept direction in activation space. A low score means the class score is not consistently sensitive to that concept. This complements Phase 6: the previous phase tells us which concepts describe classes, while TCAV asks whether the trained model's internal representation is directionally sensitive to those concepts.
